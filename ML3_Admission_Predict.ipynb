# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Admission_Predict.csv')

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
data.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95

# %%
data.shape
# Out:
# (400, 9)

# %%
data.shape
# Out:
# (400, 9)

# %%
data.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
data.dtypes
# Out:
# Serial No.             int64
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %%
display(type(data))
# Out:
# pandas.core.frame.DataFrame

# %%
#Remove Serial No.
data= data.drop('Serial No.',axis=1)
data
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# ...

# %%
data.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP        LOR   \
# count  400.000000   400.000000         400.000000  400.000000  400.000000
# mean   316.807500   107.410000           3.087500    3.400000    3.452500
# std     11.473646     6.069514           1.143728    1.006869    0.898478
# min    290.000000    92.000000           1.000000    1.000000    1.000000
# 25%    308.000000   103.000000           2.000000    2.500000    3.000000
# 50%    317.000000   107.000000           3.000000    3.500000    3.500000
# 75%    325.000000   112.000000           4.000000    4.000000    4.000000
# max    340.000000   120.000000           5.000000    5.000000    5.000000
#
#              CGPA    Research  Chance of Admit
# count  400.000000  400.000000        400.000000
# mean     8.598925    0.547500          0.724350
# std      0.596317    0.498362          0.142609
# min      6.800000    0.000000          0.340000
# 25%      8.170000    0.000000          0.640000
# ...

# %%
data['Admission_Predict'] = [1 if each > 0.88 else 0 for each in data['Chance of Admit ']]

# %%
data = data.drop('Chance of Admit ', axis=1)
data
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Admission_Predict
# 0                    1
# 1                    0
# ...

# %%
data.isnull().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Admission_Predict    0
# dtype: int64

# %%
sns.barplot(data=data, x=data['Admission_Predict'], y=data['CGPA'])
# Out:
# <AxesSubplot:xlabel='Admission_Predict', ylabel='CGPA'>

# %%
reserch = data['Research'].value_counts()
plt.pie(reserch, labels=reserch.index,autopct='%.2f')
plt.show()

# %%
sns.pairplot(data)

# %%
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
x = data.iloc[:,:-1]
y = data['Admission_Predict']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=1)

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier,plot_tree

clf_gini = DecisionTreeClassifier(criterion='gini')
clf_gini.fit(x_train,y_train)
clf_gini
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=(10,20))
plot_tree(clf_gini,filled=True)
# Out:
# [Text(0.5833333333333334, 0.9444444444444444, 'X[5] <= 9.21\ngini = 0.273\nsamples = 300\nvalue = [251, 49]'),
#  Text(0.3333333333333333, 0.8333333333333334, 'X[5] <= 9.07\ngini = 0.031\nsamples = 251\nvalue = [247, 4]'),
#  Text(0.25, 0.7222222222222222, 'gini = 0.0\nsamples = 223\nvalue = [223, 0]'),
#  Text(0.4166666666666667, 0.7222222222222222, 'X[3] <= 4.25\ngini = 0.245\nsamples = 28\nvalue = [24, 4]'),
#  Text(0.3333333333333333, 0.6111111111111112, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.5, 0.6111111111111112, 'X[1] <= 118.0\ngini = 0.408\nsamples = 14\nvalue = [10, 4]'),
#  Text(0.4166666666666667, 0.5, 'X[0] <= 327.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.3333333333333333, 0.3888888888888889, 'X[4] <= 4.75\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.25, 0.2777777777777778, 'X[5] <= 9.105\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
# ...

# %%
y_pred_gini = clf_gini.predict(x_test)

# %%
from sklearn.metrics import ConfusionMatrixDisplay,accuracy_score,precision_score,recall_score
ConfusionMatrixDisplay.from_predictions(y_test,y_pred_gini)
plt.show()

# %%
precision_score(y_test,y_pred_gini)
# Out:
# 0.875

# %%
recall_score(y_test,y_pred_gini)
# Out:
# 0.8235294117647058

# %%
accuracy_score(y_test,y_pred_gini)
# Out:
# 0.95

# %%
"Enter student details below:"


gre = float(input("GRE Score: "))
toefl = float(input("TOEFL Score: "))
univ = float(input("University Rating (1-5): "))
sop = float(input("SOP (1-5): "))
lor = float(input("LOR (1-5): "))
cgpa = float(input("CGPA: "))
research = int(input("Research (1 = Yes, 0 = No): "))


sample = [[gre, toefl, univ, sop, lor, cgpa, research]]


result = clf_gini.predict(sample)

"Student can be admitted"if result[0] == 1 else "Student cannot be admitted"
# Out:
# GRE Score: 113
# TOEFL Score: 21
# University Rating (1-5): 4.5
# SOP (1-5): 4.45
# LOR (1-5): 2
# CGPA: 8.5
# Research (1 = Yes, 0 = No): 1
# /home/student/.local/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 'Student cannot be admitted'

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.25, random_state=0
)

# %%
from sklearn.tree import DecisionTreeClassifier

clf_entropy = DecisionTreeClassifier(criterion='entropy')
clf_entropy.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred_entropy = clf_entropy.predict(x_test)

# %%
y_pred_entropy = clf_entropy.predict(x_test)
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_entropy)
plt.show()

# %%
display("Enter student details:")

gre = float(input("GRE Score: "))
toefl = float(input("TOEFL Score: "))
univ = float(input("University Rating (1-5): "))
sop = float(input("SOP (1-5): "))
lor = float(input("LOR (1-5): "))
cgpa = float(input("CGPA: "))
research = int(input("Research (1 = Yes, 0 = No): "))

sample = [[gre, toefl, univ, sop, lor, cgpa, research]]


result = clf_entropy.predict(sample)

if result[0] == 1:
    print("Student can be admitted")
else:
    print("Student cannot be admitted")
# Out:
# 'Enter student details:'
# GRE Score: 119
# TOEFL Score: 21
# University Rating (1-5): 4
# SOP (1-5): 4.5
# LOR (1-5): 3.5
# CGPA: 9.1
# Research (1 = Yes, 0 = No): 1
# Student cannot be admitted
# /home/student/.local/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
