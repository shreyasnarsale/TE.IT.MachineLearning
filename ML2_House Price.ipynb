# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('House_Price_dataset.csv')

# %%
df.shape
# Out:
# (545, 13)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420       4.0        2.0      3.0      yes        no       no
# 1  12250000  8960       4.0        4.0      4.0      yes        no       no
# 2  12250000  9960       3.0        2.0      2.0      yes        no      yes
# 3  12215000  7500       4.0        2.0      2.0      yes        no      yes
# 4  11410000  7420       4.0        1.0      2.0      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes      2.0      yes        furnished
# 1              no             yes      3.0       no        furnished
# 2              no              no      2.0      yes   semi-furnished
# 3              no             yes      3.0      yes        furnished
# 4              no             yes      2.0       no        furnished

# %%
df.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000       2.0        1.0      1.0      yes        no      yes
# 541  1767150  2400       3.0        1.0      1.0       no        no       no
# 542  1750000  3620       2.0        1.0      1.0      yes        no       no
# 543  1750000  2910       3.0        1.0      1.0       no        no       no
# 544  1750000  3850       3.0        1.0      2.0      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no      2.0       no      unfurnished
# 541              no              no      0.0       no   semi-furnished
# 542              no              no      0.0       no      unfurnished
# 543              no              no      0.0       no        furnished
# 544              no              no      0.0       no      unfurnished

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  540.000000  540.000000  543.000000
# mean   4.766729e+06   5150.541284    2.961111    1.285185    1.804788
# std    1.870440e+06   2170.141023    0.738779    0.502464    0.869011
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  541.000000
# mean     0.691312
# std      0.860070
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.dtypes
# Out:
# price                 int64
# area                  int64
# bedrooms            float64
# bathrooms           float64
# stories             float64
# mainroad             object
# guestroom            object
# basement             object
# hotwaterheating      object
# airconditioning      object
# parking             float64
# prefarea             object
# furnishingstatus     object
# dtype: object

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            5
# bathrooms           5
# stories             2
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             4
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
zeros = (df ==0).sum()
zeros
# Out:
# price                 0
# area                  0
# bedrooms              0
# bathrooms             0
# stories               0
# mainroad              0
# guestroom             0
# basement              0
# hotwaterheating       0
# airconditioning       0
# parking             297
# prefarea              0
# furnishingstatus      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
df['price'].mean()
# Out:
# np.float64(4766729.247706422)

# %%
df.mean(numeric_only=True).round()
# Out:
# price        4766729.0
# area            5151.0
# bedrooms           3.0
# bathrooms          1.0
# stories            2.0
# parking            1.0
# dtype: float64

# %%
df['bathrooms'].fillna(df['bathrooms'].mean(numeric_only=True).round())
# Out:
# 0      2.0
# 1      4.0
# 2      2.0
# 3      2.0
# 4      1.0
#       ...
# 540    1.0
# 541    1.0
# 542    1.0
# 543    1.0
# 544    1.0
# Name: bathrooms, Length: 545, dtype: float64

# %%
df['bedrooms'].fillna(df['bedrooms'].mean(numeric_only=True).round(),inplace=True)
df['stories'].fillna(df['stories'].mean(numeric_only=True).round(),inplace=True)
df['parking'].fillna(df['parking'].mean(numeric_only=True).round(),inplace=True)
df
# Out:
# C:\Users\Shreyas\AppData\Local\Temp\ipykernel_16728\677968709.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bedrooms'].fillna(df['bedrooms'].mean(numeric_only=True).round(),inplace=True)
# C:\Users\Shreyas\AppData\Local\Temp\ipykernel_16728\677968709.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
sns.pairplot(df,hue='bedrooms')

# %%
df.iloc[:100]
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0   13300000  7420       4.0        2.0      3.0      yes        no       no
# 1   12250000  8960       4.0        4.0      4.0      yes        no       no
# 2   12250000  9960       3.0        2.0      2.0      yes        no      yes
# 3   12215000  7500       4.0        2.0      2.0      yes        no      yes
# 4   11410000  7420       4.0        1.0      2.0      yes       yes      yes
# ..       ...   ...       ...        ...      ...      ...       ...      ...
# 95   6300000  4100       3.0        2.0      3.0      yes        no       no
# 96   6300000  9000       3.0        1.0      1.0      yes        no      yes
# 97   6300000  6400       3.0        1.0      1.0      yes       yes      yes
# 98   6293000  6600       3.0        2.0      3.0      yes        no       no
# 99   6265000  6000       4.0        1.0      3.0      yes       yes      yes
#
# ...

# %%
df.iloc[:,[0,1,2,3,10,12]]
# Out:
#         price  area  bedrooms  bathrooms  parking furnishingstatus
# 0    13300000  7420       4.0        2.0      2.0        furnished
# 1    12250000  8960       4.0        4.0      3.0        furnished
# 2    12250000  9960       3.0        2.0      2.0   semi-furnished
# 3    12215000  7500       4.0        2.0      3.0        furnished
# 4    11410000  7420       4.0        1.0      2.0        furnished
# ..        ...   ...       ...        ...      ...              ...
# 540   1820000  3000       2.0        1.0      2.0      unfurnished
# 541   1767150  2400       3.0        1.0      0.0   semi-furnished
# 542   1750000  3620       2.0        1.0      0.0      unfurnished
# 543   1750000  2910       3.0        1.0      0.0        furnished
# 544   1750000  3850       3.0        1.0      0.0      unfurnished
#
# [545 rows x 6 columns]

# %%
df[df['area']  > 1000]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420       4.0        2.0      3.0      yes        no       no
# 1    12250000  8960       4.0        4.0      4.0      yes        no       no
# 2    12250000  9960       3.0        2.0      2.0      yes        no      yes
# 3    12215000  7500       4.0        2.0      2.0      yes        no      yes
# 4    11410000  7420       4.0        1.0      2.0      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000       2.0        1.0      1.0      yes        no      yes
# 541   1767150  2400       3.0        1.0      1.0       no        no       no
# 542   1750000  3620       2.0        1.0      1.0      yes        no       no
# 543   1750000  2910       3.0        1.0      1.0       no        no       no
# 544   1750000  3850       3.0        1.0      2.0      yes        no       no
#
# ...

# %%
subset = df.iloc[10:151]

# %%
subset = subset.loc[df['guestroom'] == 'no']
subset = subset.loc[df['bathrooms'] >= 2]
subset
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 12   9310000   6550       4.0        2.0      2.0      yes        no       no
# 13   9240000   3500       4.0        2.0      2.0      yes        no       no
# 14   9240000   7800       3.0        2.0      2.0      yes        no       no
# 17   8960000   8500       3.0        2.0      4.0      yes        no       no
# 19   8855000   6420       3.0        2.0      2.0      yes        no       no
# 28   8400000   7950       5.0        2.0      2.0      yes        no      yes
# 29   8400000   5500       4.0        2.0      2.0      yes        no      yes
# 30   8400000   7475       3.0        2.0      4.0      yes        no       no
# 32   8295000   4880       4.0        2.0      2.0      yes        no       no
# 35   8080940   7000       3.0        2.0      4.0      yes        no       no
# 36   8043000   7482       3.0        2.0      3.0      yes        no       no
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x=df['area']
y=df['price']

# %%
train, test = train_test_split(df, test_size=0.25, random_state=42)

# %%
train.shape
# Out:
# (408, 13)

# %%
test.shape
# Out:
# (137, 13)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
print("Shape of dataset:", df.shape)
print(df.head())
# Out:
# Shape of dataset: (545, 13)
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420       4.0        2.0      3.0      yes        no       no
# 1  12250000  8960       4.0        4.0      4.0      yes        no       no
# 2  12250000  9960       3.0        2.0      2.0      yes        no      yes
# 3  12215000  7500       4.0        2.0      2.0      yes        no      yes
# 4  11410000  7420       4.0        1.0      2.0      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes      2.0      yes        furnished
# 1              no             yes      3.0       no        furnished
# 2              no              no      2.0      yes   semi-furnished
# 3              no             yes      3.0      yes        furnished
# 4              no             yes      2.0       no        furnished

# %%
print(df.columns)
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
# Independent and dependent variables
X = df[["area"]]    # feature
y = df["price"]     # label

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Train model
model_simple = LinearRegression()
model_simple.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict
y_pred_simple = model_simple.predict(X_test)

# %%
# Metrics
mse_simple = mean_squared_error(y_test, y_pred_simple)
mae_simple = mean_absolute_error(y_test, y_pred_simple)
r2_simple = r2_score(y_test, y_pred_simple)

# %%
print("\n Simple Linear Regression Metrics:")
print("MSE:", mse_simple)
print("MAE:", mae_simple)
print("R-Square:", r2_simple)
# Out:
#  Simple Linear Regression Metrics:
# MSE: 3296594592847.056
# MAE: 1401283.7270683737
# R-Square: 0.2846315616909706

# %%
# Visualization
plt.figure(figsize=(8,5))
plt.scatter(X_test, y_test, color="blue", label="Actual Data")
plt.plot(X_test, y_pred_simple, color="red", linewidth=2, label="Regression Line")
plt.xlabel("Area")
plt.ylabel("Price")
plt.title("Simple Linear Regression: Area vs Price")
plt.legend()
plt.show()

# %%
from sklearn.impute import SimpleImputer

# %%
# Use multiple features
features = ["area", "bedrooms", "bathrooms"]  # modify based on available columns
X_multi = df[features]
y_multi = df["price"]

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420       4.0        2.0      3.0      yes        no       no
# 1  12250000  8960       4.0        4.0      4.0      yes        no       no
# 2  12250000  9960       3.0        2.0      2.0      yes        no      yes
# 3  12215000  7500       4.0        2.0      2.0      yes        no      yes
# 4  11410000  7420       4.0        1.0      2.0      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes      2.0      yes        furnished
# 1              no             yes      3.0       no        furnished
# 2              no              no      2.0      yes   semi-furnished
# 3              no             yes      3.0      yes        furnished
# 4              no             yes      2.0       no        furnished

# %%
X_train_m, X_test_m, y_train_m, y_test_m = train_test_split(X_multi, y_multi, test_size=0.25, random_state=42)

# %%
target_col = 'price'   

X = df.drop(target_col, axis=1)
y = df[target_col]

X = pd.get_dummies(X, drop_first=True)

imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_imputed, y, test_size=0.2, random_state=42
)

model = LinearRegression()
model.fit(X_train, y_train)

print("Model trained successfully!")
print("Training R²:", model.score(X_train, y_train))
print("Testing R²:", model.score(X_test, y_test))
# Out:
# Model trained successfully!
# Training R²: 0.6815320980977048
# Testing R²: 0.6553725999191697

# %%
from sklearn.impute import SimpleImputer
import pandas as pd

# For numeric columns
num_imputer = SimpleImputer(strategy='mean')

# Convert to numeric if categorical columns exist
X = pd.get_dummies(X, drop_first=True)

# Apply imputer
X_imputed = num_imputer.fit_transform(X)

# Then split and train
X_train_m, X_test_m, y_train_m, y_test_m = train_test_split(
    X_imputed, y, test_size=0.2, random_state=42
)

model_multi.fit(X_train_m, y_train_m)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

y_pred_multi = model_multi.predict(X_test_m)

mse_multi = mean_squared_error(y_test_m, y_pred_multi)
mae_multi = mean_absolute_error(y_test_m, y_pred_multi)
r2_multi = r2_score(y_test_m, y_pred_multi)

print("\nMultivariate Regression Metrics:")
print("MSE:", mse_multi)
print("MAE:", mae_multi)
print("R-Square:", r2_multi)
# Out:
# Multivariate Regression Metrics:
# MSE: 1741943402528.877
# MAE: 965265.5028988133
# R-Square: 0.6553725999191697

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

y_pred = model.predict(X_test)

print("\nMultivariate Regression Metrics:")
print("MSE:", mean_squared_error(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
print("R-Square:", r2_score(y_test, y_pred))
# Out:
# Multivariate Regression Metrics:
# MSE: 1741943402528.877
# MAE: 965265.5028988133
# R-Square: 0.6553725999191697

# %%
print(df.columns.tolist())
# Out:
# ['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'parking', 'prefarea', 'furnishingstatus']

# %%
# Suppose features and label
X = df[["area"]]    # replace "Area" with your actual column name
y = df["price"]     # replace "Price" with your actual column name

# %%
# Handle missing values
imputer = SimpleImputer(strategy="mean")
X = imputer.fit_transform(X)

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Train model
model_simple = LinearRegression()
model_simple.fit(X_train, y_train)

# Predict
y_pred = model_simple.predict(X_test)

# %%
# Metrics
print("MSE:", mean_squared_error(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
print("R2:", r2_score(y_test, y_pred))
# Out:
# MSE: 3296594592847.056
# MAE: 1401283.7270683737
# R2: 0.2846315616909706
